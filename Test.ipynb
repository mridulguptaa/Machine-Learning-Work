# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=pd.read_csv('Datasets/LinearX.csv')
y=pd.read_csv('Datasets/LinearY.csv')

# %%
plt.scatter(x,y)

# %%
def hypothesis(theta,x):
    hyp=theta[0]+theta[1]*x
    return hyp
# Out:
#   File "<ipython-input-38-af3711513fb5>", line 19
#     print(m)
#         ^
# SyntaxError: invalid syntax

# %%
def error(theta,x,y):
    m=x.shape[0]
    e=0
    for i in range(m):
        hx=hypotheis(theta,x[i])
        e+=(hx-y[i])**2
    return e
        
    
    
def gradient(thete,x,y):
    
    m=x.shape[0]
    grad=np.zeros((2,)
    print(m)
    for i in range(m):
        hx=hypothesis(theta,x[i])
        grad[0]+=hx-y[i]
        grad[1]+=(hx-y[i])*x[i]
        return grad
        
    


def grad_desc(theta,x,y,learning_rate=0.001):
    m=x.shape[0]
    error=[]
    
    for i in range(100):
        
        grad=gradient(theta,x,y)
        theta[0]=theta[0]-learning_rate*grad[0]
        theta[1]=theta[1]-learning_rate*grad[1]
        
        e=error(theta,x[i],y)
        error.append(e)
    
    
    return theta,error
        



theta=np.zeros((2,))
print(theta)

final_theta,final_error=gard_desc(theta,x,y)
# Out:
#   File "<ipython-input-41-60b884f3e9e0>", line 16
#     print(m)
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
dat=pd.read_csv('Datasets\mushrooms.csv')
print(dat)
# Out:
#      type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0       p         x           s         n       t    p               f
# 1       e         x           s         y       t    a               f
# 2       e         b           s         w       t    l               f
# 3       p         x           y         w       t    p               f
# 4       e         x           s         g       f    n               f
# 5       e         x           y         y       t    a               f
# 6       e         b           s         w       t    a               f
# 7       e         b           y         w       t    l               f
# 8       p         x           y         w       t    p               f
# 9       e         b           s         y       t    a               f
# 10      e         x           y         y       t    l               f
# 11      e         x           y         y       t    a               f
# ...
