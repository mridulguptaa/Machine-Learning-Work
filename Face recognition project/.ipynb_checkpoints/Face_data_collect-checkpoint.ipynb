# %%
import cv2

# %%
#Read an image

img=cv2.imread(r"C:\Users\Mridul Gupta\Desktop\Mridul.jpg")
#cv2.imshow('Mridul',img)
img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt
plt.imshow(img)
plt.show()

# %%
plt.imshow(img2)
plt.show()

# %%
video=cv2.VideoCapture(0)
#face_cascade=cv2.CascadeClassifier(path)
face_cascade = cv2.CascadeClassifier('C:\\opencv\\build\\etc\\haarcascades\\haarcascade_frontalface_default.xml')
while True:
    ret,frame=video.read()
    
    if ret==False:
        continue
    #frame = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    faces=face_cascade.detectMultiScale(frame,1.3,5)
    
    
    
    for (x,y,z,w) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+z),(255,0,0),2)
        
    cv2.imshow("video frame",frame)
    
    key_pressed=cv2.waitKey(1)& 0xFF
    if key_pressed==ord('n'):
        break
video.release()
cv2.destroyAllWindows()
cv2.destroyAllWindows()
video.release()

# %%
import os 
list = os.listdir()
print(list)
# Out:
# ['.anaconda', '.android', '.bash_history', '.conda', '.condarc', '.gitconfig', '.Icecream Screen Recorder', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.Origin', '.QtWebEngineProcess', '.viminfo', '3D Objects', 'Anaconda3', 'ansel', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Data Visualization.ipynb', 'Datasets', 'Desktop', 'Documents', 'Downloads', 'Face detection Project-haar cascade.ipynb', 'Favorites', 'filehandling_test.txt', 'haarcascade_frontalface_alt.xml', 'Intel', 'IntelGraphicsProfiles', 'Introduction.ipynb', 'Linear regression.ipynb', 'linearX.csv', 'linearY.csv', 'Links', 'Local Settings', 'logisticX.csv', 'logisticY.csv', 'MicrosoftEdgeBackups', 'Mridul.jpg', 'Music', 'My Documents', 'MyWorkingCodes', 'NetHood', 'ntuser.dat', 'ntuser.dat.log1', 'ntuser.dat.log2', 'ntuser.dat{2719af88-a322-11e8-9c34-5800e3511e9f}.TxR.0.regtrans-ms', 'ntuser.dat{2719af88-a322-11e8-9c34-5800e3511e9f}.TxR.1.regtrans-ms', 'ntuser.dat{2719af88-a322-11e8-9c34-5800e3511e9f}.TxR.2.regtrans-ms', 'ntuser.dat{2719af88-a322-11e8-9c34-5800e3511e9f}.TxR.blf', 'ntuser.dat{2719af89-a322-11e8-9c34-5800e3511e9f}.TM.blf', 'ntuser.dat{2719af89-a322-11e8-9c34-5800e3511e9f}.TMContainer00000000000000000001.regtrans-ms', 'ntuser.dat{2719af89-a322-11e8-9c34-5800e3511e9f}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.dat{62132851-a306-11e8-9c37-c85b76a287ed}.TM.blf', 'ntuser.dat{62132851-a306-11e8-9c37-c85b76a287ed}.TMContainer00000000000000000001.regtrans-ms', 'ntuser.dat{62132851-a306-11e8-9c37-c85b76a287ed}.TMContainer00000000000000000002.regtrans-ms', 'NTUSER.DAT{74719d1a-9d79-11e8-bb28-f632c547c250}.TM.blf', 'NTUSER.DAT{74719d1a-9d79-11e8-bb28-f632c547c250}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{74719d1a-9d79-11e8-bb28-f632c547c250}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'Practise.ipynb', 'PrintHood', 'Python Contest Hackerblocks.ipynb', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'train.csv', 'Untitled Folder 1', 'Untitled.ipynb', 'Videos', 'xdata.csv', 'ydata.csv']

# %%
cv2.__version__
# Out:
# '3.4.3'
